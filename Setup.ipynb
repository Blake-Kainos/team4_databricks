# %%
import pandas as pd
import os

# Shared path in Databricks Unity Catalog Volume - accessible to all team members
# Upload Food_Inspections.csv to this location once via Databricks UI:
# Catalog → Volumes → your volume → Upload
VOLUME_CSV_PATH = "/Volumes/students_data/team4-chicago/chicago-restaurants"

file_name = "food_inspections_raw.csv"
full_path = os.path.join(VOLUME_CSV_PATH, file_name)

print(f"Volume path: {VOLUME_CSV_PATH}")
print(f"File name:   {file_name}")
print(f"Full path:   {full_path}")
print(f"\nVolume exists: {os.path.isdir(VOLUME_CSV_PATH)}")

if os.path.isdir(VOLUME_CSV_PATH):
    files = os.listdir(VOLUME_CSV_PATH)
    print(f"Files in volume ({len(files)}):")
    for f in files:
        print(f"  - {f}")
    print(f"\nTarget file exists: {os.path.isfile(full_path)}")
else:
    print("⚠️ Volume path not found — check catalog/schema/volume names.")
